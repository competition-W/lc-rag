# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

from ChunkerMaster.hyper_paramter import GLOBAL_DIMENSION, CHUNK_SIZE, CHUNK_OVERLAP

# %%
print(GlOBAL_DIMENSION)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(GlOBAL_DIMENSION)
#
# NameError: name 'GlOBAL_DIMENSION' is not defined

# %%
from ..ChunkerMaster.hyper_paramter import hyper_parameter
print(hyper_parameter.CHUNK_OVERLAP)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from .ChunkerMaster.hyper_paramter import hyper_parameter
#       2 print(hyper_parameter.CHUNK_OVERLAP)
#
# ImportError: attempted relative import with no known parent package

# %%
from build_gpu_index_0703 import GLOBAL_DIMENSION

# %%
GLOBAL_DIMENSION
# Out:
# 1024
